# %%
import matplotlib.pyplot as plt

training_dataset_sizes = ["500k", "400k", "300k", "200k", "100k"]
ks = [
    [40, 40, 100, 160, 140, 50, 60, 60, 250, 240], 
    [60, 10, 70, 160, 290, 50, 10, 120, 100, 1870], 
    [40, 140, 120, 80, 480, 20, 50, 110, 130, 320], 
    # [0], 
    [80, 510, 110, 200, 360, 40, 240, 230, 260, 500]
]

plt.boxplot(ks, tick_labels=training_dataset_sizes, showfliers=False)
plt.xlabel("Training Dataset Sizes")
plt.ylabel("Knn Before First Intersection")
plt.title("K Nearest Neighbors Necessary for Non-Zero Intersection by Training Dataset Sizes")
plt.savefig("KNN.png")
plt.show()
